# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath(".."))

from scripts.visualization import (
    sentiment_distribution,
    rating_distribution,
    theme_frequency
)

from scripts.insights import bank_summary, drivers_and_pain_points

# %%
drivers, pains = drivers_and_pain_points()
drivers.head(10)
# Out:
#    bank_name    identified_theme  count
# 8     Dashen               Other    279
# 10    Dashen               UI/UX     36
# 9     Dashen  Transaction Issues      4
# 7     Dashen      Account Issues      1
# 3        CBE               Other    315
# 6        CBE               UI/UX     16
# 5        CBE  Transaction Issues      7
# 4        CBE  Performance Issues      1
# 1        BOA               Other    261
# 0        BOA      Account Issues      2

# %%
pains.head(10)
# Out:
#    bank_name    identified_theme  count
# 11    Dashen               Other    144
# 13    Dashen  Transaction Issues     14
# 12    Dashen  Performance Issues     10
# 14    Dashen               UI/UX      7
# 10    Dashen      Account Issues      5
# 6        CBE               Other    130
# 8        CBE  Transaction Issues     16
# 7        CBE  Performance Issues      9
# 9        CBE               UI/UX      5
# 5        CBE      Account Issues      1

# %%
sentiment, rating = bank_summary()
sentiment
# Out:
# bank_name
# BOA       0.075663
# CBE       0.367424
# Dashen    0.288774
# Name: sentiment_score, dtype: float64

# %%
rating
# Out:
# bank_name
# BOA       3.574
# CBE       4.122
# Dashen    3.928
# Name: rating, dtype: float64

# %%
fig = sentiment_distribution()
plt.show()

# %%
fig = rating_distribution()
plt.show()

# %%
fig = theme_frequency()
plt.show()
